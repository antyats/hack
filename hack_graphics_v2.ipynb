# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set(style="darkgrid")

np.random.seed(0)

# %%
df = pd.read_csv("auc-0.84.csv")
df = final_df.rename(columns={'ed_num': 'education_type'})


corr = df[['age', 'country', 'edu_num', 'work_cnt', 'is_working',
                 'transformer_proba', 'set_inter', 'know_english',
                  'language_count', 'mean_work_dur',
                  'new_transformer_proba', 'sex', 'new_keywords_score',
                 'education_type', 'work_age', 'skills_count',
                 'target']].corr()
sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
# Out:
# <Axes: >

# %%
df
# Out:
#                                                  about  birth_date  \
# 0                                                  NaN  1979-01-01
# 1     (Гражданин Республики Казахстан, по России им...  1991-01-01
# 2     С 1999 года, после появления дома первого ком...  1986-12-08
# 3    - Oracle Certified Associate, Java SE 7 Progra...  1985-10-13
# 4                                                  NaN  1992-07-28
# ..                                                 ...         ...
# 651                                                NaN  1995-01-01
# 652                                                NaN  1988-11-14
# 653                                                NaN  1992-06-02
# 654   Профессиональные навыки: • JavaScript, базовы...  2000-01-01
# 655   Я имеют опыт работы с Vue.js (более 5 лет), J...  1998-02-16
#
#                 city  country first_name  \
# 0    Санкт-Петербург        1     Данила
# 1             Москва        1      Савва
# ...

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение возраста кандидатов', fontsize=15)
ax.set_xlabel('Возраст')
ax.set_ylabel('Количество')
sns.histplot(df['age'],
             bins=30,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение количества образований у кандидатов', fontsize=15)
ax.set_xlabel('Образование')
ax.set_ylabel('Количество')
sns.histplot(df.edu_num,
             bins=30,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение ступеней образований у кандидатов', fontsize=15)
ax.set_xlabel('Образование')
ax.set_ylabel('Количество')
sns.histplot(df.education_type,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение количества работ у кандидатов', fontsize=15)
ax.set_xlabel('Работы')
ax.set_ylabel('Количество')
sns.histplot(df.work_cnt,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Знание языков у кандидатов', fontsize=15)
ax.set_xlabel('Количество языков')
ax.set_ylabel('Количество кандидатов')
sns.histplot(df.language_count,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Количество скиллов кандидатов', fontsize=15)
ax.set_xlabel('Скиллы')
ax.set_ylabel('Количество кандидатов')
sns.histplot(df.skills_count,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение относительного к жизни опыта кандидатов', fontsize=15)
ax.set_xlabel('Опыт')
ax.set_ylabel('Количество кандидатов')
sns.histplot(df.work_age,
             ax=ax, 
             color='pink',
             edgecolor='purple');

# %%
fig, ax = plt.subplots(figsize=(6, 6))
plt.pie(df.know_english.value_counts().values, labels=["не знают", "знают"], autopct='%1.1f%%')
plt.title("Знание английского языка")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
plt.pie(df.is_working.value_counts().values, labels=["работают", "не работают"], autopct='%1.1f%%')
plt.title("Работа на данный момент")
plt.show()

# %%
df.target.value_counts()
# Out:
# target
# 0    463
# 1    193
# Name: count, dtype: int64

# %%
yes = df[df.target == 1]
no = df[df.target == 0]

# %%
len(no)
# Out:
# 463

# %%
df.language_count.value_counts()
# Out:
# language_count
# 0    356
# 2    223
# 1     46
# 3     26
# 4      4
# 5      1
# Name: count, dtype: int64

# %%
yes.language_count.value_counts()
# Out:
# language_count
# 0    193
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение получивших работу по знанию языков', fontsize=15)
ax.set_xlabel('Количество')
ax.set_ylabel('Языки')
sns.countplot(y=yes.language_count,
              ax=ax);

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение не получивших работу по знанию языков', fontsize=15)
ax.set_xlabel('Количество')
ax.set_ylabel('Языки')
sns.countplot(y=no.language_count,
              ax=ax);

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение получивших работу по полу', fontsize=15)
ax.set_xlabel('Количество')
ax.set_ylabel('Пол')
sns.countplot(y=yes.sex,
              ax=ax);

# %%
fig, ax = plt.subplots(figsize=(9, 6))
ax.set_title('Распределение не получивших работу по полу', fontsize=15)
ax.set_xlabel('Количество')
ax.set_ylabel('Пол')
sns.countplot(y=no.sex,
              ax=ax);

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.set_title('Распределение времени работы', fontsize=15)
ax.set_xlabel('Не попали на работу/попали')
ax.set_ylabel('Среднее время работы')
sns.boxplot(y=df.mean_work_dur, x=df.target,
              ax=ax)
ax.set_ylim(top=4000)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.set_title('Распределение времени работы относительно времени жизни', fontsize=15)
ax.set_xlabel('Не попали на работу/попали')
ax.set_ylabel('Отношение работа/жизнь')
sns.boxplot(y=df.work_age, x=df.target,
              ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax.set_title('Распределение возраста', fontsize=15)
ax.set_xlabel('Не попали на работу/попали')
ax.set_ylabel('Возраст')
sns.boxplot(y=df.age, x=df.target,
              ax=ax)
plt.show()
